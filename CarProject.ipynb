# %%
#import libraries
import numpy as np
import pandas as pd

# %%
#import dataset
ds=pd.read_csv("quikr_car.csv")
ds
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
#year
ds["year"].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
ds["year"].str.isnumeric()
ds=ds.dropna()
ds["year"]=ds["year"].astype(int)
# Out:
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_14268\2231966791.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds["year"]=ds["year"].astype(int)

# %%
#price
ds["Price"].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
ds["Price"].str.isnumeric()
ds["Price"]=ds["Price"].str.replace(",","")
# Out:
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_14268\1491541102.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds["Price"]=ds["Price"].str.replace(",","")

# %%
for i in ds.index:
    if ds.loc[i,"Price"]=="Ask For Price":
        ds.drop(i,inplace=True)

# %%
#kms_driven
ds["kms_driven"].unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
ds["kms_driven"].str.isnumeric()
ds["kms_driven"]=ds["kms_driven"].str.replace(" kms","")
ds["kms_driven"]=ds["kms_driven"].str.replace(",","")
ds["kms_driven"].astype(int)
# Out:
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_14268\2970950462.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds["kms_driven"]=ds["kms_driven"].str.replace(" kms","")
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_14268\2970950462.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds["kms_driven"]=ds["kms_driven"].str.replace(",","")
# 0       45000
# 1          40
# 3       28000
# 4       36000
# 6       41000
#         ...
# 883     50000
# 885     30000
# 886    132000
# ...

# %%
#fuel
ds["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
ds.dropna(inplace=True)
# Out:
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_14268\2725967003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds.dropna(inplace=True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int32
#  3   Price       816 non-null    object
#  4   kms_driven  816 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 73.7+ KB

# %%
#company
for i in ds.index:
    company=ds.loc[i,"company"]
    name=ds.loc[i,"name"]
    name=name.replace("company"," ").strip()
    ds.loc[i,"name"]=name

# %%
ds.drop_duplicates(inplace = True)
# Out:
# C:\Users\Sanika\AppData\Local\Temp\ipykernel_14268\658634312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds.drop_duplicates(inplace = True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        724 non-null    object
#  1   company     724 non-null    object
#  2   year        724 non-null    int32
#  3   Price       724 non-null    object
#  4   kms_driven  724 non-null    object
#  5   fuel_type   724 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 36.8+ KB

# %%
#new indexing
ds.reset_index(inplace = True)
ds
# Out:
#      level_0  index                                    name   company  year  \
# 0          0      0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007
# 1          1      1                 Mahindra Jeep CL550 MDI  Mahindra  2006
# 2          2      3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014
# 3          3      4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014
# 4          4      6                               Ford Figo      Ford  2012
# ..       ...    ...                                     ...       ...   ...
# 719      719    883              Maruti Suzuki Ritz VXI ABS    Maruti  2011
# 720      720    885               Tata Indica V2 DLE BS III      Tata  2009
# 721      721    886                    Toyota Corolla Altis    Toyota  2009
# 722      722    888                     Tata Zest XM Diesel      Tata  2018
# 723      723    889                      Mahindra Quanto C8  Mahindra  2013
#
#       Price kms_driven fuel_type
# ...

# %%
#Dividing data into X(independent) and y(Dependent)
X=ds[["name","company","year","kms_driven","fuel_type"]]
y=ds[["Price"]]

# %%
X
# Out:
#                                        name   company  year kms_driven  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007      45000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006         40
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014      28000
# 3          Ford EcoSport Titanium 1.5L TDCi      Ford  2014      36000
# 4                                 Ford Figo      Ford  2012      41000
# ..                                      ...       ...   ...        ...
# 719              Maruti Suzuki Ritz VXI ABS    Maruti  2011      50000
# 720               Tata Indica V2 DLE BS III      Tata  2009      30000
# 721                    Toyota Corolla Altis    Toyota  2009     132000
# 722                     Tata Zest XM Diesel      Tata  2018      27000
# 723                      Mahindra Quanto C8  Mahindra  2013      40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Diesel
# 4      Diesel
# ..        ...
# ...

# %%
y
# Out:
#       Price
# 0     80000
# 1    425000
# 2    325000
# 3    575000
# 4    175000
# ..      ...
# 719  270000
# 720  110000
# 721  300000
# 722  260000
# 723  390000
#
# [724 rows x 1 columns]

# %%
X["company"].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
for i in ds.index:
    company=ds.loc[i,"company"]
    name=ds.loc[i,"name"]
    name=name.replace(company,"").strip()
    ds.loc[i,"name"]=name

# %%
ds
# Out:
#      level_0  index                            name   company  year   Price  \
# 0          0      0    Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1          1      1                  Jeep CL550 MDI  Mahindra  2006  425000
# 2          2      3  Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3          3      4     EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 4          4      6                            Figo      Ford  2012  175000
# ..       ...    ...                             ...       ...   ...     ...
# 719      719    883             Suzuki Ritz VXI ABS    Maruti  2011  270000
# 720      720    885            Indica V2 DLE BS III      Tata  2009  110000
# 721      721    886                   Corolla Altis    Toyota  2009  300000
# 722      722    888                  Zest XM Diesel      Tata  2018  260000
# 723      723    889                       Quanto C8  Mahindra  2013  390000
#
#     kms_driven fuel_type
# 0        45000    Petrol
# ...

# %%
ds.to_csv("NewCar")

# %%
#Read the cleaned dataset
#import dataset
ds=pd.read_csv("Cleaned-data.csv")
ds
# Out:
#      Unnamed: 0  index                            name   company  year  \
# 0             0      0    Santro Xing XO eRLX Euro III   Hyundai  2007
# 1             1      1                  Jeep CL550 MDI  Mahindra  2006
# 2             2      3  Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014
# 3             3      4     EcoSport Titanium 1.5L TDCi      Ford  2014
# 4             4      6                            Figo      Ford  2012
# ..          ...    ...                             ...       ...   ...
# 719         719    883             Suzuki Ritz VXI ABS    Maruti  2011
# 720         720    885            Indica V2 DLE BS III      Tata  2009
# 721         721    886                   Corolla Altis    Toyota  2009
# 722         722    888                  Zest XM Diesel      Tata  2018
# 723         723    889                       Quanto C8  Mahindra  2013
#
#       Price  kms_driven fuel_type
# 0     80000       45000    Petrol
# 1    425000          40    Diesel
# ...

# %%
#Dividing data into X(Independent) and y(Dependent)
X=ds[["name","company","year","kms_driven","fuel_type"]]
y=ds[["Price"]]

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import make_pipeline

# %%
#OneHotEncoding
ohe=OneHotEncoder()
ohe.fit(X[["name","company","fuel_type"]])
X
# Out:
#                                name   company  year  kms_driven fuel_type
# 0      Santro Xing XO eRLX Euro III   Hyundai  2007       45000    Petrol
# 1                    Jeep CL550 MDI  Mahindra  2006          40    Diesel
# 2    Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       28000    Petrol
# 3       EcoSport Titanium 1.5L TDCi      Ford  2014       36000    Diesel
# 4                              Figo      Ford  2012       41000    Diesel
# ..                              ...       ...   ...         ...       ...
# 719             Suzuki Ritz VXI ABS    Maruti  2011       50000    Petrol
# 720            Indica V2 DLE BS III      Tata  2009       30000    Diesel
# 721                   Corolla Altis    Toyota  2009      132000    Petrol
# 722                  Zest XM Diesel      Tata  2018       27000    Diesel
# 723                       Quanto C8  Mahindra  2013       40000    Diesel
#
# [724 rows x 5 columns]

# %%
#Column transformer
ct=make_column_transformer((OneHotEncoder(categories=ohe.categories_),["name","company","fuel_type"]),remainder="passthrough")
reg=DecisionTreeRegressor()
pipe=make_pipeline(ct,reg)
X
# Out:
#                                name   company  year  kms_driven fuel_type
# 0      Santro Xing XO eRLX Euro III   Hyundai  2007       45000    Petrol
# 1                    Jeep CL550 MDI  Mahindra  2006          40    Diesel
# 2    Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       28000    Petrol
# 3       EcoSport Titanium 1.5L TDCi      Ford  2014       36000    Diesel
# 4                              Figo      Ford  2012       41000    Diesel
# ..                              ...       ...   ...         ...       ...
# 719             Suzuki Ritz VXI ABS    Maruti  2011       50000    Petrol
# 720            Indica V2 DLE BS III      Tata  2009       30000    Diesel
# 721                   Corolla Altis    Toyota  2009      132000    Petrol
# 722                  Zest XM Diesel      Tata  2018       27000    Diesel
# 723                       Quanto C8  Mahindra  2013       40000    Diesel
#
# [724 rows x 5 columns]

# %%
#Training and Testing
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.01,random_state=2)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
y_pred
# Out:
# array([ 60000., 750000., 225000., 175000., 330000., 209000., 179000.,
#        280000.])

# %%
#make pipeline and divide data into x(independent) & y(dependent)
from sklearn.metrics import r2_score
scores = []
for i in range(0, 100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = i)
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    score = r2_score(y_test, y_pred)
    scores.append(score)

# %%
index = np.argmax(scores)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = index)
pipe.fit(X_train, y_train)
y_pred=pipe.predict(X_train)

# %%
y_pred
# Out:
# array([ 160000.,  115000.,  260000.,  240000.,  195000.,  525000.,
#         390000.,  159000.,  475000.,  189500.,  170000.,  110000.,
#         280000.,  270000.,  105000.,  265000.,  155000.,  400000.,
#         244999.,  449999.,  580000.,  490000.,  450000.,  490000.,
#         169500.,  285000.,  860000.,  299999.,   85000.,  210000.,
#         125000.,  475000.,  190000.,  900000.,  135000.,  265000.,
#         300000.,  130000.,  580000.,  280000.,  100000.,   85000.,
#         550000.,  450000., 1600000.,  224999.,  415000.,  330000.,
#         350000.,  200000.,  320000.,   45000.,  899000.,  120000.,
#         760000.,  270000.,  199000.,  123000.,  450000.,   50500.,
#         500000.,   70000.,  390000.,  200000.,   57000.,  300000.,
#         210000.,  295000.,  240000.,  380000.,  830000.,  120000.,
#         120000.,  699000.,  750000.,  800000.,  185000.,  125000.,
#         340000.,   95000.,  245000., 1225000.,  325000.,  130000.,
# ...

# %%
#Prediction
myinput = np.array(["Honda","Amaze",2013,46000,"Diesel"]).reshape(1, 5)
columns = ["company","name","year","kms_driven","fuel_type"]
mydata = pd.DataFrame(columns =columns,data=myinput)
result = pipe.predict(mydata)
print("Expected Price:",result[0])
# Out:
# Expected Price: 299000.0

# %%
import pickle

# %%
with open('DecisionTree.pkl','wb') as file:
    pickle.dump(pipe,file)
